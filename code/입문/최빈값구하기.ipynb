# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/120812

# %% [markdown]
# #### 문제 설명
# 최빈값은 주어진 값 중에서 가장 자주 나오는 값을 의미합니다. 정수 배열 array가 매개변수로 주어질 때, 최빈값을 return 하도록 solution 함수를 완성해보세요. 최빈값이 여러 개면 -1을 return 합니다.

# %% [markdown]
# #### 제한사항
# 0 < array의 길이 < 100
# 0 ≤ array의 원소 < 1000

# %% [markdown]
# #### 입출력 예
# array	            result
# [1, 2, 3, 3, 3, 4]	3
# [1, 1, 2, 2]	    -1
# [1]	                1

# %% [markdown]
# ## 풀이

# %%
def solution(array):
    answer = 0
    
    nums = list(set(array))
    cnts = []
    for num in nums:
        cnts.append(array.count(num))
    cnt = max(cnts)
    if cnts.count(cnt) > 1:
        answer = -1
    else:
        answer = nums[cnts.index(cnt)]
    
    return answer

solution([1, 2, 3, 3, 3, 4])
# Out:
# 3

# %% [markdown]
# ## 다른 풀이

# %%
from collections import Counter

def solution(array):
    cnts = Counter(array).most_common(2)
    if cnts[0][0] != cnts[-1][0] and cnts[0][1] == cnts[-1][1]:
        return -1
    return cnts[0][0]

solution([1, 2, 3, 3, 3, 4])
# Out:
# 3

# %%
from collections import Counter

def solution(array):
    cnts = Counter(array)
    max_num = max(cnts, key=cnts.get)
    max_cnt = max(cnts.values())
    if list(cnts.values()).count(max_cnt) > 1:
        return -1
    else: 
        return max_num
    
solution([1, 2, 3, 3, 3, 4])
# Out:
# 3
