# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/120829

# %% [markdown]
# ## 문제 풀이

# %%
def solution(angle):
    d,m = divmod(angle,90)
    if m == 0:
        return 2*d
    else:
        return 1+2*d
    
solution(70)
# Out:
# 1
