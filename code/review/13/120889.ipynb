# %% [markdown]
# ## 삼각형의 완성조건 (1)

# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/120889

# %% [markdown]
# ## 문제 풀이

# %%
def solution(sides):
    sides = sorted(sides)
    return int(sides[-1] >= sum(sides[:-1]))+1

solution([1, 2, 3])
# Out:
# 2
