# %% [markdown]
# ## 최댓값 만들기(1)

# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/120847

# %% [markdown]
# ## 문제 풀이

# %%
from functools import reduce
def solution(numbers):
    return reduce(lambda x,y: x*y, sorted(numbers)[-2:])

solution([0, 31, 24, 10, 1, 9])
# Out:
# 744
