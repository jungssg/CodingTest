# %% [markdown]
# ## 나이 출력

# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/120820

# %% [markdown]
# ## 문제 풀이

# %%
def solution(age):
    year = 2022
    birth = year - age + 1
    return birth

solution(40)
# Out:
# 1983
