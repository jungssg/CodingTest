# %% [markdown]
# ## 문자 반복 출력하기

# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/120825

# %% [markdown]
# ## 문제 풀이

# %%
def solution(my_string, n):
    answer = ''
    for ch in my_string:
        answer += ch*n
    return answer

solution('hello', 3)
# Out:
# 'hhheeellllllooo'
