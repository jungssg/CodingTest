# %% [markdown]
# ## 두 수의 차

# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/120803

# %% [markdown]
# ## 문제 풀이

# %%
def solution(num1, num2):
    answer = num1 - num2
    return answer

solution(2,3)
# Out:
# -1
