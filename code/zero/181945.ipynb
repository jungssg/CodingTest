# %% [markdown]
# ## 문자열 돌리기

# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/181945

# %% [markdown]
# ## 문제 풀이

# %%
str = input()
print('\n'.join(str))
# Out:
# a
# b
# c
# d
# e
