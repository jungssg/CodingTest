# %% [markdown]
# ## 가위 바위 보

# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/120839

# %% [markdown]
# ## 문제 풀이

# %%
def solution(rsp):
    win = {'2':'0','0':'5','5':'2'}
    return ''.join([win[x] for x in rsp])

solution("205")
# Out:
# '052'
