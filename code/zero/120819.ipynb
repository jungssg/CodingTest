# %% [markdown]
# ## 아이스 아메리카노

# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/120819

# %% [markdown]
# ## 문제 풀이

# %%
def solution(money):
    return [money//5500, money%5500]

solution(15000)
# Out:
# [2, 4000]
