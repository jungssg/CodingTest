# %% [markdown]
# ## 양꼬치

# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/120830

# %% [markdown]
# ## 문제 풀이

# %%
def solution(n, k):
    return n*12000 + (k-n//10)*2000

solution(10,3)
# Out:
# 124000
