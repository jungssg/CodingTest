# %% [markdown]
# ## 짝수는 싫어요

# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/120813

# %% [markdown]
# ## 문제 풀이

# %%
def solution(n):
    answer = sorted(range(1, n+1, 2))
    return answer

solution(10)
# Out:
# [1, 3, 5, 7, 9]
