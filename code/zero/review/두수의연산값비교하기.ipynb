# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/181938

# %% [markdown]
# ## 문제 풀이

# %%
def solution(a, b):
    answer = 0
    
    ab = ''.join(map(str,[a,b]))
    ab = int(ab)
    answer = max(ab, 2*a*b)
    
    return answer

solution(2,91)
# Out:
# 364
