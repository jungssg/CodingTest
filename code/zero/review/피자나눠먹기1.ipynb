# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/120814

# %% [markdown]
# ## 문제 풀이

# %%
def solution(n):
    answer = 1
    
    if n%7==0:
        answer = n//7
    else:
        answer = n//7+1
    
    return answer

solution(7)
# Out:
# 1
