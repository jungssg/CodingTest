# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/181941

# %% [markdown]
# ## 문제 풀이

# %%
def solution(arr):
    answer = ''.join(arr)
    return answer

solution(["a","b","c"])
# Out:
# 'abc'
