# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/181940

# %% [markdown]
# ## 문제 풀이

# %%
def solution(my_string, k):
    answer = my_string*k
    return answer

solution("string",3)
# Out:
# 'stringstringstring'
