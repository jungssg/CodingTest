# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/120903

# %% [markdown]
# ## 문제 설명
# 두 배열이 얼마나 유사한지 확인해보려고 합니다. 문자열 배열 s1과 s2가 주어질 때 같은 원소의 개수를 return하도록 solution 함수를 완성해주세요.
#
# - 제한사항
# 1 ≤ s1, s2의 길이 ≤ 100
# 1 ≤ s1, s2의 원소의 길이 ≤ 10
# s1과 s2의 원소는 알파벳 소문자로만 이루어져 있습니다
# s1과 s2는 각각 중복된 원소를 갖지 않습니다.

# %% [markdown]
# - 입출력 예
# s1	s2	result
# ["a", "b", "c"]	["com", "b", "d", "p", "c"]	2
# ["n", "omg"]	["m", "dot"]	0
#
# 입출력 예 설명
#
# - 입출력 예 #1
#
# "b"와 "c"가 같으므로 2를 return합니다.
#
# - 입출력 예 #2
#
# 같은 원소가 없으므로 0을 return합니다.

# %%
def solution(s1, s2):
    answer = 0
    for n in s1:
        if n in s2:
            answer += 1
    return  answer

# %% [markdown]
# ## 다른풀이

# %% [markdown]
# ### intersection함수는 교집합을 구하는 함수이고 list형태에서는 작동하지 않아 반드시 set의 형태로 변환해줘야한다
# ### 그런데 index의 경우에는 set을 씌워주지 않더라도 index 자체로 intersection이 적용됨
# (참고)https://herjh0405.tistory.com/85

# %%
# intersection함수는 교집합을 구하는 함수이고 list형태에서는 작동하지 않아 반드시 set의 형태로 변환해줘야한다
def solution(s1, s2):
    s1 = set(s1)
    s2 = set(s2)
    return len(s1.intersection(s2))
