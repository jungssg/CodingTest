# %% [markdown]
# ## 문제 설명
# 다음과 같이 출력하도록 코드를 작성해 주세요.
#
# 출력 예시
#
# !@#$%^&*(\'"<>?:;

# %%
str = '!@#$%^&*(\\\'"<>?:;'
print(str)
# Out:
# !@#$%^&*(\'"<>?:;

# %%
print(r'!@#$%^&*(\'"<>?:;')
# Out:
# !@#$%^&*(\'"<>?:;
